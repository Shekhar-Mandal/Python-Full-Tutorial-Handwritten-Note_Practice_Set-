# %%
# # file handling is used to perform different operation on a file (read and write)
# type of files:
# 1.Text file (.txt,.log,.docx here data is in character form)
# 2.binary file(.mp4,.png,.jpeg  here none text file except charcter )



# open a file 
f=open('hello.txt','r')
data=f.read()
print(data)
print(type(f))
print(type(data))
f.close()
# Out:
# hello i am shekhar mandal
# <class '_io.TextIOWrapper'>
# <class 'str'>

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.1
# pip 25.2 from C:\Users\HomePC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip (python 3.12)

# %%
pip install tensorflow

# %%
import os

if os.path.exists("hello.txt"):
    print("File found!")
else:
    print("File does not exist")
# Out:
# File found!

# %%
class Animal:
    species ="DOG"
    def make_bark(self):
        print("bark")


print(Animal().species)
Animal().make_bark()
# Out:
# DOG
# bark
